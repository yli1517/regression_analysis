# %%
import api_call as api
import transform_response as t
import data_cleaning as clean
import test_data_cleaning as test
import requests
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = clean.full_clean()
# Out:
# /Users/marissaeppes/Desktop/Mod_3_Project/module_3_project/data_cleaning.py:50: RuntimeWarning: divide by zero encountered in log
#   df[log_var] = np.log(df[var])

# %%
result = api.call_api()

# %%
df = t.get_dataframe(result)

# %%
df = clean.lowercase_columns(df)

# %%
df.head()
# Out:
#        emp emp_s empszfi                       empszfi_ttl eth_group  \
# 1  6973459   1.3     641     Firms with 20 to 49 employees       001
# 2  4663039   2.8     642     Firms with 50 to 99 employees       001
# 3  4689659   2.4     651   Firms with 100 to 249 employees       001
# 4  2725228   6.2     652   Firms with 250 to 499 employees       001
# 5  8775515   2.1     657  Firms with 500 employees or more       001
#
#   eth_group_ttl firmpdemp firmpdemp_s     geo_id        geo_ttl  ...  \
# 1     All firms    231413         1.4  0100000US  United States  ...
# 2     All firms     68449         2.8  0100000US  United States  ...
# 3     All firms     31606         2.5  0100000US  United States  ...
# 4     All firms      7988         6.3  0100000US  United States  ...
# 5     All firms      5205         4.7  0100000US  United States  ...
#
#   rcpszfi_ttl  sex     sex_ttl  st vet_group vet_group_ttl  year yibszfi  \
# ...

# %%
df = clean.make_numeric(df)

# %%
df.head()
# Out:
#        emp emp_s  empszfi                       empszfi_ttl  eth_group  \
# 1  6973459   1.3      641     Firms with 20 to 49 employees          1
# 2  4663039   2.8      642     Firms with 50 to 99 employees          1
# 3  4689659   2.4      651   Firms with 100 to 249 employees          1
# 4  2725228   6.2      652   Firms with 250 to 499 employees          1
# 5  8775515   2.1      657  Firms with 500 employees or more          1
#
#   eth_group_ttl  firmpdemp firmpdemp_s     geo_id        geo_ttl  ...  \
# 1     All firms     231413         1.4  0100000US  United States  ...
# 2     All firms      68449         2.8  0100000US  United States  ...
# 3     All firms      31606         2.5  0100000US  United States  ...
# 4     All firms       7988         6.3  0100000US  United States  ...
# 5     All firms       5205         4.7  0100000US  United States  ...
#
#    rcpszfi_ttl sex     sex_ttl  st  vet_group vet_group_ttl  year yibszfi  \
# ...

# %%
df.dtypes
# Out:
# emp                int64
# emp_s             object
# empszfi            int64
# empszfi_ttl       object
# eth_group          int64
# eth_group_ttl     object
# firmpdemp          int64
# firmpdemp_s       object
# geo_id            object
# geo_ttl           object
# geotype            int64
# msa               object
# naics2012         object
# naics2012_ttl     object
# payann             int64
# payann_s          object
# race_group        object
# race_group_ttl    object
# rcppdemp           int64
# rcppdemp_s        object
# rcpszfi            int64
# rcpszfi_ttl       object
# sex                int64
# sex_ttl           object
# st                object
# vet_group          int64
# vet_group_ttl     object
# year              object
# yibszfi           object
# yibszfi_ttl       object
# us                object
# dtype: object

# %%
df.head()
# Out:
#        emp emp_s  empszfi                       empszfi_ttl  eth_group  \
# 1  6973459   1.3      641     Firms with 20 to 49 employees          1
# 2  4663039   2.8      642     Firms with 50 to 99 employees          1
# 3  4689659   2.4      651   Firms with 100 to 249 employees          1
# 4  2725228   6.2      652   Firms with 250 to 499 employees          1
# 5  8775515   2.1      657  Firms with 500 employees or more          1
#
#   eth_group_ttl  firmpdemp firmpdemp_s     geo_id        geo_ttl  ...  \
# 1     All firms     231413         1.4  0100000US  United States  ...
# 2     All firms      68449         2.8  0100000US  United States  ...
# 3     All firms      31606         2.5  0100000US  United States  ...
# 4     All firms       7988         6.3  0100000US  United States  ...
# 5     All firms       5205         4.7  0100000US  United States  ...
#
#    rcpszfi_ttl sex     sex_ttl  st  vet_group vet_group_ttl  year yibszfi  \
# ...

# %%
t.save_csv(df)

# %%
# !pwd
# Out:
# /Users/marissaeppes/Desktop/Mod_3_Project/module_3_project

# %%
df = clean.response_to_df_csv()

# %%
df.head()
# Out:
# 0      EMP EMP_S EMPSZFI                       EMPSZFI_TTL ETH_GROUP  \
# 1  6973459   1.3     641     Firms with 20 to 49 employees       001
# 2  4663039   2.8     642     Firms with 50 to 99 employees       001
# 3  4689659   2.4     651   Firms with 100 to 249 employees       001
# 4  2725228   6.2     652   Firms with 250 to 499 employees       001
# 5  8775515   2.1     657  Firms with 500 employees or more       001
#
# 0 ETH_GROUP_TTL FIRMPDEMP FIRMPDEMP_S     GEO_ID        GEO_TTL  ...  \
# 1     All firms    231413         1.4  0100000US  United States  ...
# 2     All firms     68449         2.8  0100000US  United States  ...
# 3     All firms     31606         2.5  0100000US  United States  ...
# 4     All firms      7988         6.3  0100000US  United States  ...
# 5     All firms      5205         4.7  0100000US  United States  ...
#
# 0 RCPSZFI_TTL  SEX     SEX_TTL  ST VET_GROUP VET_GROUP_TTL  YEAR YIBSZFI  \
# ...

# %%
df = clean.lowercase_columns(df)

# %%
df.columns
# Out:
# Index(['emp', 'emp_s', 'empszfi', 'empszfi_ttl', 'eth_group', 'eth_group_ttl',
#        'firmpdemp', 'firmpdemp_s', 'geo_id', 'geo_ttl', 'geotype', 'msa',
#        'naics2012', 'naics2012_ttl', 'payann', 'payann_s', 'race_group',
#        'race_group_ttl', 'rcppdemp', 'rcppdemp_s', 'rcpszfi', 'rcpszfi_ttl',
#        'sex', 'sex_ttl', 'st', 'vet_group', 'vet_group_ttl', 'year', 'yibszfi',
#        'yibszfi_ttl', 'us'],
#       dtype='object')

# %%
df.duplicated(keep = False).unique()
# Out:
# array([False])

# %%
duplicated_entries = df[df.duplicated(keep=False)]

# %%
len(duplicated_entries)
# Out:
# 0

# %%
test.test_if_dataframe(df)

# %%
test.test_column_name_whitespace(df)

# %%
test.test_no_null_values(df)

# %%
test.test_column_name_lowercase(df)

# %%
new_df = clean.full_clean()

# %%
test = clean.drop_zero_pay(new_df)

# %%
new_df
# Out:
#              emp  empszfi                       empszfi_ttl  eth_group  \
# 0        6973459      641     Firms with 20 to 49 employees          1
# 1        4663039      642     Firms with 50 to 99 employees          1
# 2        4689659      651   Firms with 100 to 249 employees          1
# 3        2725228      652   Firms with 250 to 499 employees          1
# 4        8775515      657  Firms with 500 employees or more          1
# 5        6696450        1                         All firms          1
# 6         316697        1                         All firms          1
# 7         607482        1                         All firms          1
# 8         518691        1                         All firms          1
# 9        1275486        1                         All firms          1
# 10       3144473        1                         All firms          1
# 11        833622        1                         All firms          1
# ...

# %%
response = api.call_api()

# %%
df = t.get_dataframe(response)

# %%
df.columns
# Out:
# Index(['EMP', 'EMP_S', 'EMPSZFI', 'EMPSZFI_TTL', 'ETH_GROUP', 'ETH_GROUP_TTL',
#        'FIRMPDEMP', 'FIRMPDEMP_S', 'GEO_ID', 'GEO_TTL', 'GEOTYPE', 'MSA',
#        'NAICS2012', 'NAICS2012_TTL', 'PAYANN', 'PAYANN_S', 'RACE_GROUP',
#        'RACE_GROUP_TTL', 'RCPPDEMP', 'RCPPDEMP_S', 'RCPSZFI', 'RCPSZFI_TTL',
#        'SEX', 'SEX_TTL', 'ST', 'VET_GROUP', 'VET_GROUP_TTL', 'YEAR', 'YIBSZFI',
#        'YIBSZFI_TTL', 'us'],
#       dtype='object', name=0)

# %%
t.save_csv(df)

# %%
a = clean.full_clean()

# %%
a
# Out:
#              emp  empszfi                       empszfi_ttl  eth_group  \
# 0        6973459      641     Firms with 20 to 49 employees          1
# 1        4663039      642     Firms with 50 to 99 employees          1
# 2        4689659      651   Firms with 100 to 249 employees          1
# 3        2725228      652   Firms with 250 to 499 employees          1
# 4        8775515      657  Firms with 500 employees or more          1
# 5        6696450        1                         All firms          1
# 6         316697        1                         All firms          1
# 7         607482        1                         All firms          1
# 8         518691        1                         All firms          1
# 9        1275486        1                         All firms          1
# 10       3144473        1                         All firms          1
# 11        833622        1                         All firms          1
# ...

# %%
clean.full_clean()
# Out:
#              emp  empszfi                       empszfi_ttl  eth_group  \
# 0        6973459      641     Firms with 20 to 49 employees          1
# 1        4663039      642     Firms with 50 to 99 employees          1
# 2        4689659      651   Firms with 100 to 249 employees          1
# 3        2725228      652   Firms with 250 to 499 employees          1
# 4        8775515      657  Firms with 500 employees or more          1
# 5        6696450        1                         All firms          1
# 6         316697        1                         All firms          1
# 7         607482        1                         All firms          1
# 8         518691        1                         All firms          1
# 9        1275486        1                         All firms          1
# 10       3144473        1                         All firms          1
# 11        833622        1                         All firms          1
# ...

# %%
response = api.call_api()

# %%
df = t.get_dataframe(response)

# %%
clean.response_to_df_csv()
# Out:
# 0            EMP EMP_S EMPSZFI                       EMPSZFI_TTL ETH_GROUP  \
# 1        6973459   1.3     641     Firms with 20 to 49 employees       001
# 2        4663039   2.8     642     Firms with 50 to 99 employees       001
# 3        4689659   2.4     651   Firms with 100 to 249 employees       001
# 4        2725228   6.2     652   Firms with 250 to 499 employees       001
# 5        8775515   2.1     657  Firms with 500 employees or more       001
# 6        6696450   1.5     001                         All firms       001
# 7         316697   3.7     001                         All firms       001
# 8         607482   3.3     001                         All firms       001
# 9         518691   3.2     001                         All firms       001
# 10       1275486   3.4     001                         All firms       001
# 11       3144473   2.3     001                         All firms       001
# ...

# %%
test = clean.full_clean()

# %%
import numpy as np

# %%
test['payann_log'] = np.log(test.payann)

# %%
test.payann_log
# Out:
# 0        19.491662
# 1        19.155862
# 2        19.214134
# 3        18.710196
# 4        19.672264
# 5        19.140708
# 6        15.851202
# 7        16.451219
# 8        16.345956
# 9        17.387754
# 10       18.493648
# 11       17.151754
# 12       13.317321
# 13       17.020558
# 14       19.009493
# 15       15.820926
# 16       15.815695
# 17       19.065842
# 18       12.951143
# 19       13.408581
# 20       14.272050
# 21       15.813530
# 22       16.518703
# 23       17.015423
# 24       18.865054
# 25       14.897454
# 26       17.017811
# 27       17.165702
# 28       22.453324
# 29       18.193435
#            ...
# 15026    10.894385
# 15027    10.244379
# 15028    11.257594
# 15029    13.304498
# 15031    11.536007
# 15032    11.084417
# 15033    13.572792
# 15036    13.751978
# 15037     7.379632
# 15038    10.278528
# 15039    10.814203
# 15040    12.163416
# 15041    12.208325
# 15042    12.077284
# 15043    12.623529
# 15044    11.356599
# ...

# %%
test = clean.full_clean()

# %%
test = clean.add_log_col(test)

# %%
np.log(3)
# Out:
# 1.0986122886681098

# %%
np.log([4,5])
# Out:
# array([1.38629436, 1.60943791])

# %%
df.head()
# Out:
# 0      EMP EMP_S EMPSZFI                       EMPSZFI_TTL ETH_GROUP  \
# 1  6973459   1.3     641     Firms with 20 to 49 employees       001
# 2  4663039   2.8     642     Firms with 50 to 99 employees       001
# 3  4689659   2.4     651   Firms with 100 to 249 employees       001
# 4  2725228   6.2     652   Firms with 250 to 499 employees       001
# 5  8775515   2.1     657  Firms with 500 employees or more       001
#
# 0 ETH_GROUP_TTL FIRMPDEMP FIRMPDEMP_S     GEO_ID        GEO_TTL  ...  \
# 1     All firms    231413         1.4  0100000US  United States  ...
# 2     All firms     68449         2.8  0100000US  United States  ...
# 3     All firms     31606         2.5  0100000US  United States  ...
# 4     All firms      7988         6.3  0100000US  United States  ...
# 5     All firms      5205         4.7  0100000US  United States  ...
#
# 0 RCPSZFI_TTL  SEX     SEX_TTL  ST VET_GROUP VET_GROUP_TTL  YEAR YIBSZFI  \
# ...
